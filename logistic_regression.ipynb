# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanth-challa199/machine-learning-part/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-69c74ec6-aef0-4915-b151-0745e97272f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69c74ec6-aef0-4915-b151-0745e97272f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/insurance_data(logistic regression).csv')
print(df)
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

df=pd.read_csv('/content/insurance_data(logistic regression).csv')
print(df)

x=df[['age']]
y=df['bought_insurance']

plt.scatter(x,y,marker='*',color='blue')

plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.show()

model=LogisticRegression()
model.fit(x,y)
print('prediction')
print(model.predict([[93]]))
print()
print()

#scores
print('scores')
print(model.score(x,y))
print()
print()
#probabilty
print('probability')
print(model.predict_proba(x))
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0
# prediction
# [1]
#
#
# scores
# 0.8888888888888888
#
#
# probability
# [[0.90742163 0.09257837]
#  [0.86716891 0.13283109]
#  [0.24897544 0.75102456]
#  [0.14412896 0.85587104]
#  [0.27515592 0.72484408]
# ...
